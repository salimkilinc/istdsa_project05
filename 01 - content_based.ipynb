# %% [markdown]
# # Modeling Content-Based Filtering Recommender System

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import joblib

# %%
df = pd.read_csv('wines_and_ratings.csv', low_memory=False, compression="zstd")
df
# Out:
#         RatingID   UserID  Rating Vintage  \
# 0            143  1356810     4.5    1950
# 1            199  1173759     5.0    1951
# 2            348  1164877     5.0    1952
# 3            374  1207665     5.0    1953
# 4            834  1075841     5.0    1955
# ...          ...      ...     ...     ...
# 149995  21013438  1000052     4.5    N.V.
# 149996  21013467  1180844     4.0    N.V.
# 149997  21013494  1218581     3.5    N.V.
# 149998  21013505  1106198     4.5    N.V.
# 149999  21013509  1059173     5.0    N.V.
#
#                                    WineName   ABV              Body Acidity  \
# 0                Presidential Colheita Port  14.5  Very full bodied    High
# 1       Pauillac  Premier Grand Cru Classé   13.0       Full bodied    High
# 2       Pauillac  Premier Grand Cru Classé   13.0       Full bodied    High
# 3           Saint Julien  Grand Cru Classé   13.5       Full bodied    High
# 4           Saint Julien  Grand Cru Classé   14.0       Full bodied    High
# ...                                     ...   ...               ...     ...
# 149995       Blanc de Blancs Brut Champagne  12.5     Medium bodied    High
# 149996        Brut  R de Ruinart  Champagne  12.0     Medium bodied    High
# 149997   Crémant d Alsace Cuvée Julien Brut  12.5      Light bodied    High
# 149998       Blanc de Blancs Brut Champagne  12.5     Medium bodied    High
# 149999         Impérial Rosé Brut Champagne  12.0     Medium bodied    High
#
#          Country        RegionName  ...   Harmonize3   Harmonize4 Harmonize5  \
# 0       Portugal             Porto  ...  Hard Cheese          NaN        NaN
# 1         France          Pauillac  ...    Game Meat      Poultry        NaN
# 2         France          Pauillac  ...    Game Meat      Poultry        NaN
# 3         France      Saint Julien  ...    Game Meat      Poultry        NaN
# 4         France      Saint Julien  ...    Game Meat      Poultry        NaN
# ...          ...               ...  ...          ...          ...        ...
# 149995    France         Champagne  ...    Shellfish  Soft Cheese        NaN
# 149996    France         Champagne  ...    Shellfish  Soft Cheese        NaN
# 149997    France  Crémant d Alsace  ...    Appetizer        Snack  Lean Fish
# 149998    France         Champagne  ...    Shellfish  Soft Cheese        NaN
# 149999    France         Champagne  ...    Shellfish  Soft Cheese        NaN
#
#        Harmonize6 Harmonize7 Harmonize8 Harmonize9 Harmonize10 Harmonize11  \
# 0             NaN        NaN        NaN        NaN         NaN         NaN
# 1             NaN        NaN        NaN        NaN         NaN         NaN
# 2             NaN        NaN        NaN        NaN         NaN         NaN
# 3             NaN        NaN        NaN        NaN         NaN         NaN
# 4             NaN        NaN        NaN        NaN         NaN         NaN
# ...           ...        ...        ...        ...         ...         ...
# 149995        NaN        NaN        NaN        NaN         NaN         NaN
# 149996        NaN        NaN        NaN        NaN         NaN         NaN
# 149997        NaN        NaN        NaN        NaN         NaN         NaN
# 149998        NaN        NaN        NaN        NaN         NaN         NaN
# 149999        NaN        NaN        NaN        NaN         NaN         NaN
#
#        Harmonize12
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 149995         NaN
# 149996         NaN
# 149997         NaN
# 149998         NaN
# 149999         NaN
#
# [150000 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 37 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   RatingID     150000 non-null  int64
#  1   UserID       150000 non-null  int64
#  2   Rating       150000 non-null  float64
#  3   Vintage      150000 non-null  object
#  4   WineName     150000 non-null  object
#  5   ABV          150000 non-null  float64
#  6   Body         150000 non-null  object
#  7   Acidity      150000 non-null  object
#  8   Country      150000 non-null  object
#  9   RegionName   150000 non-null  object
#  10  WineryName   150000 non-null  object
#  11  Website      150000 non-null  object
#  12  Type1        150000 non-null  object
#  13  Type2        2522 non-null    object
#  14  Elaborate1   150000 non-null  object
#  15  Elaborate2   150000 non-null  object
#  16  Grapes1      150000 non-null  object
#  17  Grapes2      44538 non-null   object
#  18  Grapes3      28735 non-null   object
#  19  Grapes4      15134 non-null   object
#  20  Grapes5      5070 non-null    object
#  21  Grapes6      1866 non-null    object
#  22  Grapes7      919 non-null     object
#  23  Grapes8      862 non-null     object
#  24  Grapes9      804 non-null     object
#  25  Harmonize1   150000 non-null  object
#  26  Harmonize2   149778 non-null  object
#  27  Harmonize3   146425 non-null  object
#  28  Harmonize4   108107 non-null  object
#  29  Harmonize5   30055 non-null   object
#  30  Harmonize6   12094 non-null   object
#  31  Harmonize7   1109 non-null    object
#  32  Harmonize8   670 non-null     object
#  33  Harmonize9   391 non-null     object
#  34  Harmonize10  250 non-null     object
#  35  Harmonize11  202 non-null     object
#  36  Harmonize12  202 non-null     object
# dtypes: float64(2), int64(2), object(33)
# memory usage: 42.3+ MB

# %% [markdown]
# ## Combining Selected Columns into a Single 'Attributes' Column

# %%
df = df.fillna("")
common_columns = ['WineName', 'Body', 'Acidity', 'Country', 'RegionName', 'WineryName']
type_columns = ['Type1', 'Type2']
elaborate_columns = ['Elaborate1', 'Elaborate2']
grapes_columns = [f'Grapes{i}' for i in range(1, 10)]
harmonize_columns = [f'Harmonize{i}' for i in range(1, 13)]
all_columns = common_columns + type_columns + elaborate_columns + grapes_columns + harmonize_columns
df['Attributes'] = df[all_columns].astype(str).agg(' '.join, axis=1)
df
# Out:
#         RatingID   UserID  Rating Vintage  \
# 0            143  1356810     4.5    1950
# 1            199  1173759     5.0    1951
# 2            348  1164877     5.0    1952
# 3            374  1207665     5.0    1953
# 4            834  1075841     5.0    1955
# ...          ...      ...     ...     ...
# 149995  21013438  1000052     4.5    N.V.
# 149996  21013467  1180844     4.0    N.V.
# 149997  21013494  1218581     3.5    N.V.
# 149998  21013505  1106198     4.5    N.V.
# 149999  21013509  1059173     5.0    N.V.
#
#                                    WineName   ABV              Body Acidity  \
# 0                Presidential Colheita Port  14.5  Very full bodied    High
# 1       Pauillac  Premier Grand Cru Classé   13.0       Full bodied    High
# 2       Pauillac  Premier Grand Cru Classé   13.0       Full bodied    High
# 3           Saint Julien  Grand Cru Classé   13.5       Full bodied    High
# 4           Saint Julien  Grand Cru Classé   14.0       Full bodied    High
# ...                                     ...   ...               ...     ...
# 149995       Blanc de Blancs Brut Champagne  12.5     Medium bodied    High
# 149996        Brut  R de Ruinart  Champagne  12.0     Medium bodied    High
# 149997   Crémant d Alsace Cuvée Julien Brut  12.5      Light bodied    High
# 149998       Blanc de Blancs Brut Champagne  12.5     Medium bodied    High
# 149999         Impérial Rosé Brut Champagne  12.0     Medium bodied    High
#
#          Country        RegionName  ...   Harmonize4 Harmonize5 Harmonize6  \
# 0       Portugal             Porto  ...
# 1         France          Pauillac  ...      Poultry
# 2         France          Pauillac  ...      Poultry
# 3         France      Saint Julien  ...      Poultry
# 4         France      Saint Julien  ...      Poultry
# ...          ...               ...  ...          ...        ...        ...
# 149995    France         Champagne  ...  Soft Cheese
# 149996    France         Champagne  ...  Soft Cheese
# 149997    France  Crémant d Alsace  ...        Snack  Lean Fish
# 149998    France         Champagne  ...  Soft Cheese
# 149999    France         Champagne  ...  Soft Cheese
#
#        Harmonize7 Harmonize8 Harmonize9 Harmonize10 Harmonize11 Harmonize12  \
# 0
# 1
# 2
# 3
# 4
# ...           ...        ...        ...         ...         ...         ...
# 149995
# 149996
# 149997
# 149998
# 149999
#
#                                                Attributes
# 0       Presidential Colheita Port Very full bodied Hi...
# 1       Pauillac  Premier Grand Cru Classé  Full bodie...
# 2       Pauillac  Premier Grand Cru Classé  Full bodie...
# 3       Saint Julien  Grand Cru Classé  Full bodied Hi...
# 4       Saint Julien  Grand Cru Classé  Full bodied Hi...
# ...                                                   ...
# 149995  Blanc de Blancs Brut Champagne Medium bodied H...
# 149996  Brut  R de Ruinart  Champagne Medium bodied Hi...
# 149997  Crémant d Alsace Cuvée Julien Brut Light bodie...
# 149998  Blanc de Blancs Brut Champagne Medium bodied H...
# 149999  Impérial Rosé Brut Champagne Medium bodied Hig...
#
# [150000 rows x 38 columns]

# %% [markdown]
# ## Removing Duplicate Rows based on the 'Attributes' and 'WineName' Columns

# %%
df.drop_duplicates(subset=['Attributes'], inplace=True)
df.drop_duplicates(subset=['WineName'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#      RatingID   UserID  Rating Vintage                              WineName  \
# 0         143  1356810     4.5    1950            Presidential Colheita Port
# 1         199  1173759     5.0    1951   Pauillac  Premier Grand Cru Classé
# 2         374  1207665     5.0    1953       Saint Julien  Grand Cru Classé
# 3        1020  1147051     5.0    1955      Saint Estèphe  Grand Cru Classé
# 4        1664  1173759     5.0    1958                   Barolo  Tradizione
# ..        ...      ...     ...     ...                                   ...
# 798  20587832  1138481     3.5    N.V.                Blu Prosecco Extra Dry
# 799  20591243  1271440     4.5    N.V.  Grappa di Amarone della Valpolicella
# 800  20593813  1004772     3.0    N.V.                       Blanc de Blancs
# 801  20612284  1239551     4.0    N.V.                Vecchia Grappa Moscato
# 802  20760893  1003951     4.0    N.V.        Grappa Cru Monovitigno Picolit
#
#       ABV               Body Acidity        Country             RegionName  \
# 0    14.5   Very full bodied    High       Portugal                  Porto
# 1    13.0        Full bodied    High         France               Pauillac
# 2    13.5        Full bodied    High         France           Saint Julien
# 3    12.8        Full bodied    High         France          Saint Estèphe
# 4    14.0   Very full bodied    High          Italy                 Barolo
# ..    ...                ...     ...            ...                    ...
# 798  12.5  Very light bodied    High          Italy               Prosecco
# 799  14.5        Full bodied    High          Italy           Valpolicella
# 800  12.9      Medium bodied    High  United States          Sonoma County
# 801  14.5        Full bodied    High         Brazil           Serra Gaúcha
# 802  14.5      Medium bodied    High          Italy  Friuli Venezia Giulia
#
#      ...  Harmonize4  Harmonize5 Harmonize6 Harmonize7 Harmonize8 Harmonize9  \
# 0    ...
# 1    ...     Poultry
# 2    ...     Poultry
# 3    ...     Poultry
# 4    ...   Game Meat
# ..   ...         ...         ...        ...        ...        ...        ...
# 798  ...       Snack  Cured Meat
# 799  ...
# 800  ...   Lean Fish
# 801  ...
# 802  ...  Cured Meat
#
#     Harmonize10 Harmonize11 Harmonize12  \
# 0
# 1
# 2
# 3
# 4
# ..          ...         ...         ...
# 798
# 799
# 800
# 801
# 802
#
#                                             Attributes
# 0    Presidential Colheita Port Very full bodied Hi...
# 1    Pauillac  Premier Grand Cru Classé  Full bodie...
# 2    Saint Julien  Grand Cru Classé  Full bodied Hi...
# 3    Saint Estèphe  Grand Cru Classé  Full bodied H...
# 4    Barolo  Tradizione  Very full bodied High Ital...
# ..                                                 ...
# 798  Blu Prosecco Extra Dry Very light bodied High ...
# 799  Grappa di Amarone della Valpolicella Full bodi...
# 800  Blanc de Blancs Medium bodied High United Stat...
# 801  Vecchia Grappa Moscato Full bodied High Brazil...
# 802  Grappa Cru Monovitigno Picolit Medium bodied H...
#
# [803 rows x 38 columns]

# %% [markdown]
# ## Converting 'Attributes' into a TF-IDF Matrix

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['Attributes'])
tfidf_matrix.shape
# Out:
# (803, 2176)

# %% [markdown]
# ## Computing Cosine Similarity between Wines based on TF-IDF Matrix

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ## Testing the Model

# %%
def get_recommendations(WineName):
    idx = df.index[df['WineName'] == WineName].tolist()[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    wine_indices = [i[0] for i in sim_scores]
    return df['WineName'].iloc[wine_indices]

# %%
get_recommendations('Vecchia Grappa Moscato')
# Out:
# 780       Colheita Tardia Malvasia Moscato
# 36                                Moscatel
# 301                         Moscato d Asti
# 772                                Moscato
# 601                  Dulcis Moscato d Asti
# 196                     Espumante Moscatel
# 344    Moncalvina Moscato d Asti  Canelli
# 311                     101 Moscato d Asti
# 74             Aquarela Moscatel Espumante
# 716        Colheita Tardia Malvasia Bianca
# Name: WineName, dtype: object

# %% [markdown]
# ## Exporting the Model

# %%
joblib.dump((cosine_sim, df), 'content_based_recommender_model.pkl')
# Out:
# ['content_based_recommender_model.pkl']
